# %% [markdown]
# # Experiments

# %%
from sereia import Sereia
from sereia.evaluation import EvaluationHandler

# %%
database_credentials = "mongodb://root:root%40server@localhost:27017/admin"
DATASET_NAME = 'imdb'

# %%
sereia = Sereia(
    DATASET_NAME,
    database_credentials,
    config_directory='./config/',
    topk_qms=200,
    max_qm_size=5,
    max_cjn_size=3,
    topk_cjns=35,
    topk_cjns_per_qm=1,
    assume_golden_standards_in_topk=True,
)

# %%
# sereia.create_indexes()

# %%
sereia.use_database(DATASET_NAME)

# %%
sereia.use_queryset(DATASET_NAME)

# %%
sereia.load_indexes()

# %%
sereia.print_runtime_configs()
# Out:
# Maximum QM size: 5
# Top-K QMs considered: 200
# Maximum CJN size: 3
# Top-K CJNs considered: 35
# Maximum CJNs per QM: 1

# %%
result = sereia.run_queryset()
# Out:
# Found casablanca
# Running keyword query: denzel + washington
# Assuming golden CJN for denzel + washington ([['denzel', 'washington']])in position 1
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'denzel washington'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: clint + eastwood
# Assuming golden CJN for clint + eastwood ([['clint', 'eastwood']])in position 3
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'clint eastwood'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: will + smith
# Assuming golden CJN for will + smith ([['will', 'smith']])in position 3
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'will smith'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: harrison + ford
# Assuming golden CJN for harrison + ford ([['harrison', 'ford']])in position 2
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'harrison ford'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: tom + hanks
# Assuming golden CJN for tom + hanks ([['tom', 'hanks']])in position 2
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'tom hanks'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: johnny + depp
# Assuming golden CJN for johnny + depp ([['johnny', 'depp']])in position 2
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'johnny depp'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: angelina + jolie
# Assuming golden CJN for angelina + jolie ([['angelina', 'jolie']])in position 2
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'angelina jolie'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: morgan + freeman
# Assuming golden CJN for morgan + freeman ([['morgan', 'freeman']])in position 2
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'morgan freeman'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: gone with the wind
# Assuming golden CJN for gone with the wind (['gone', 'wind'])in position 2
# Generated query
# [{'$match': {'$expr': {'$regexMatch': {'input': '$title',
#                                        'options': 'i',
#                                        'regex': 'wind'}}}},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$title',
#                                        'options': 'i',
#                                        'regex': 'gone'}}}},
#  {'$project': {'id': 1}}]
# Running keyword query: star + wars
# Assuming golden CJN for star + wars ([['star', 'wars']])in position 3
# Generated query
# [{'$match': {'$expr': {'$regexMatch': {'input': '$original_title',
#                                        'options': 'i',
#                                        'regex': 'star wars'}}}},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$title',
#                                        'options': 'i',
#                                        'regex': 'star wars'}}}},
#  {'$project': {'id': 1}}]
# Running keyword query: casablanca movie
# Generated query
# [{'$match': {'$expr': {'$regexMatch': {'input': '$tagline',
#                                        'options': 'i',
#                                        'regex': 'casablanca'}}}},
#  {'$project': {'id': 1}}]
# Running keyword query: lord of the rings
# Assuming golden CJN for lord of the rings (['lord', 'rings'])in position 2
# Generated query
# [{'$match': {'$expr': {'$regexMatch': {'input': '$title',
#                                        'options': 'i',
#                                        'regex': 'lord'}}}},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$title',
#                                        'options': 'i',
#                                        'regex': 'rings'}}}},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$original_title',
#                                        'options': 'i',
#                                        'regex': 'lord'}}}},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$original_title',
#                                        'options': 'i',
#                                        'regex': 'rings'}}}},
#  {'$project': {'id': 1}}]
# Running keyword query: wizard of oz
# Assuming golden CJN for wizard of oz (['wizard', 'oz'])in position 3
# Generated query
# [{'$match': {'$expr': {'$regexMatch': {'input': '$title',
#                                        'options': 'i',
#                                        'regex': 'wizard'}}}},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$title',
#                                        'options': 'i',
#                                        'regex': 'oz'}}}},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$original_title',
#                                        'options': 'i',
#                                        'regex': 'wizard'}}}},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$original_title',
#                                        'options': 'i',
#                                        'regex': 'oz'}}}},
#  {'$project': {'id': 1}}]
# Running keyword query: the notebook
# Assuming golden CJN for the notebook (['notebook'])in position 1
# Generated query
# [{'$match': {'$expr': {'$regexMatch': {'input': '$title',
#                                        'options': 'i',
#                                        'regex': 'notebook'}}}},
#  {'$project': {'id': 1}}]
# Running keyword query: forrest + gump
# Assuming golden CJN for forrest + gump ([['forrest', 'gump']])in position 1
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.character',
#                                        'options': 'i',
#                                        'regex': 'forrest gump'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: the princess bride
# Generated query
# [{'$match': {'$expr': {'$regexMatch': {'input': '$overview',
#                                        'options': 'i',
#                                        'regex': 'princess'}}}},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$overview',
#                                        'options': 'i',
#                                        'regex': 'bride'}}}},
#  {'$project': {'id': 1}}]
# Running keyword query: the godfather
# Assuming golden CJN for the godfather (['godfather'])in position 2
# Generated query
# [{'$match': {'$expr': {'$regexMatch': {'input': '$title',
#                                        'options': 'i',
#                                        'regex': 'godfather'}}}},
#  {'$project': {'id': 1}}]
# Running keyword query: title indiana + jones
# Assuming golden CJN for title indiana + jones (['title', ['indiana', 'jones']])in position 2
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.character',
#                                        'options': 'i',
#                                        'regex': 'indiana jones'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$lookup': {'as': 'movies',
#               'foreignField': 'd',
#               'from': 'movies',
#               'localField': 'i'}},
#  {'$unwind': '$movies'},
#  {'$project': {'id': 1, 'movies.id': 1}}]
# Running keyword query: title james + bond
# Assuming golden CJN for title james + bond (['title', ['james', 'bond']])in position 5
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.character',
#                                        'options': 'i',
#                                        'regex': 'james bond'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$lookup': {'as': 'movies',
#               'foreignField': 'd',
#               'from': 'movies',
#               'localField': 'i'}},
#  {'$unwind': '$movies'},
#  {'$project': {'id': 1, 'movies.id': 1}}]
# Running keyword query: title hannibal + lecter
# Assuming golden CJN for title hannibal + lecter (['title', ['hannibal', 'lecter']])in position 2
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.character',
#                                        'options': 'i',
#                                        'regex': 'hannibal lecter'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$lookup': {'as': 'movies',
#               'foreignField': 'd',
#               'from': 'movies',
#               'localField': 'i'}},
#  {'$unwind': '$movies'},
#  {'$project': {'id': 1, 'movies.id': 1}}]
# Running keyword query: title norman + bates
# Assuming golden CJN for title norman + bates (['title', ['norman', 'bates']])in position 4
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.character',
#                                        'options': 'i',
#                                        'regex': 'normal bates'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$lookup': {'as': 'movies',
#               'foreignField': 'd',
#               'from': 'movies',
#               'localField': 'i'}},
#  {'$unwind': '$movies'},
#  {'$project': {'id': 1, 'movies.id': 1}}]
# Running keyword query: title darth + vader
# Assuming golden CJN for title darth + vader (['title', ['darth', 'vader']])in position 2
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.character',
#                                        'options': 'i',
#                                        'regex': 'darth vader'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$lookup': {'as': 'movies',
#               'foreignField': 'd',
#               'from': 'movies',
#               'localField': 'i'}},
#  {'$unwind': '$movies'},
#  {'$project': {'id': 1, 'movies.id': 1}}]
# Running keyword query: name jack + ryan
# Generated query
# [{'$set': {'crew_dup': '$crew'}},
#  {'$unwind': '$crew_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$crew_dup.name',
#                                        'options': 'i',
#                                        'regex': 'jack ryan'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: name terminator
# Generated query
# [{'$match': {'$expr': {'$regexMatch': {'input': '$tagline',
#                                        'options': 'i',
#                                        'regex': 'terminator'}}}},
#  {'$project': {'id': 1}}]
# Running keyword query: harrison + ford george + lucas
# Assuming golden CJN for harrison + ford george + lucas ([['harrison', 'ford'], ['george', 'lucas']])in position 3
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'harrison ford'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$set': {'crew_dup': '$crew'}},
#  {'$unwind': '$crew_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$crew_dup.name',
#                                        'options': 'i',
#                                        'regex': 'george lucas'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]
# Running keyword query: reeves wachowski
# Assuming golden CJN for reeves wachowski (['reeves', 'wachowski'])in position 3
# Generated query
# [{'$set': {'crew_dup': '$crew'}},
#  {'$unwind': '$crew_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$crew_dup.name',
#                                        'options': 'i',
#                                        'regex': 'wachowski'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'reeves'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]

# %%
# result = sereia.run_queryset()

# %%
evaluation_handler = EvaluationHandler(
    DATASET_NAME,
    sereia.config,
)

evaluation_handler.load_golden_standards()

# %%
evaluated_results = evaluation_handler.evaluate_results(
    result,
    results_filename='results/' + DATASET_NAME + '-Assisted',
)
# Out:
# QM Evaluation {'mrr': 0.4342993028476899, 'p@1': 0.11538461538461539, 'p@2': 0.5384615384615384, 'p@3': 0.7692307692307693, 'p@4': 0.8076923076923077, 'p@5': 0.8461538461538461, 'p@6': 0.8461538461538461, 'p@7': 0.8846153846153846, 'p@8': 0.9230769230769231, 'p@9': 0.9230769230769231, 'p@10': 0.9230769230769231, 'relevant_positions': [1, 3, 3, 2, 2, 2, 2, 2, 2, 3, 31, 2, 3, 1, 1, 24, 2, 2, 5, 2, 4, 2, 7, 8, 3, 3]}
# CJN Evaluation {'mrr': 0.4332267091882476, 'p@1': 0.11538461538461539, 'p@2': 0.5384615384615384, 'p@3': 0.7692307692307693, 'p@4': 0.8076923076923077, 'p@5': 0.8461538461538461, 'p@6': 0.8461538461538461, 'p@7': 0.8846153846153846, 'p@8': 0.8846153846153846, 'p@9': 0.8846153846153846, 'p@10': 0.8846153846153846, 'relevant_positions': [1, 3, 3, 2, 2, 2, 2, 2, 2, 3, 26, 2, 3, 1, 1, 24, 2, 2, 5, 2, 4, 2, 7, 11, 3, 3]}
# Results filename: results/imdb-Assisted

# %%
# # # # # result['results'][0].qms()
# # # # # result['results'][0].cjns()
# # # # # result['results'][0].qms()
# # # # # sereia.index_handler.value_index['casablanca']

# sereia.execute_mongo_query('credits', 
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'will smith'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}])

# %% [markdown]
# # Loading data from results file

# %%
import json

results_file = f'results/{DATASET_NAME}-Assisted.json'

# %%
with open(results_file) as f:
    results_data = json.load(f)

# %%
num_qms = results_data['evaluation']['num_query_matches']
num_cns = results_data['evaluation']['num_candidate_networks']

# %%
quality_results = results_data['evaluation']
quality_results['retrieval_score']
# Out:
# [{'keyword_query': 'denzel + washington',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 48,
#   'num_documents_expected': 48},
#  {'keyword_query': 'clint + eastwood',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 63,
#   'num_documents_expected': 63},
#  {'keyword_query': 'will + smith',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 30,
#   'num_documents_expected': 30},
#  {'keyword_query': 'harrison + ford',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 58,
#   'num_documents_expected': 58},
#  {'keyword_query': 'tom + hanks',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 71,
#   'num_documents_expected': 71},
#  {'keyword_query': 'johnny + depp',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 69,
#   'num_documents_expected': 69},
#  {'keyword_query': 'angelina + jolie',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 40,
#   'num_documents_expected': 40},
#  {'keyword_query': 'morgan + freeman',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 85,
#   'num_documents_expected': 85},
#  {'keyword_query': 'gone with the wind',
#   'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'num_documents_retrieved': 3,
#   'num_documents_expected': 1},
#  {'keyword_query': 'star + wars',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 11,
#   'num_documents_expected': 11},
#  {'keyword_query': 'casablanca movie',
#   'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'num_documents_retrieved': 3,
#   'num_documents_expected': 1},
#  {'keyword_query': 'lord of the rings',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 4,
#   'num_documents_expected': 4},
#  {'keyword_query': 'wizard of oz',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 5,
#   'num_documents_expected': 5},
#  {'keyword_query': 'the notebook',
#   'precision': 0.5,
#   'recall': 1.0,
#   'num_documents_retrieved': 4,
#   'num_documents_expected': 2},
#  {'keyword_query': 'forrest + gump',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 1,
#   'num_documents_expected': 1},
#  {'keyword_query': 'the princess bride',
#   'precision': 0.0,
#   'recall': 0.0,
#   'num_documents_retrieved': 5,
#   'num_documents_expected': 1},
#  {'keyword_query': 'the godfather',
#   'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'num_documents_retrieved': 12,
#   'num_documents_expected': 4},
#  {'keyword_query': 'title indiana + jones',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 5,
#   'num_documents_expected': 5},
#  {'keyword_query': 'title james + bond',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 27,
#   'num_documents_expected': 27},
#  {'keyword_query': 'title hannibal + lecter',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 4,
#   'num_documents_expected': 4},
#  {'keyword_query': 'title darth + vader',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 9,
#   'num_documents_expected': 9},
#  {'keyword_query': 'name terminator',
#   'precision': 0.0,
#   'recall': 0.0,
#   'num_documents_retrieved': 2,
#   'num_documents_expected': 5},
#  {'keyword_query': 'harrison + ford george + lucas',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 10,
#   'num_documents_expected': 10},
#  {'keyword_query': 'reeves wachowski',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 5,
#   'num_documents_expected': 5}]

# %%
# result['results'][24].qms()
precision_data = []
recall_data = []
for item in quality_results['retrieval_score']:
    # print(item)
    precision_data.append(item['precision'])
    recall_data.append(item['recall'])

# %%
sum(precision_data)/len(precision_data)
# Out:
# 0.8125

# %%
sum(recall_data)/len(recall_data)
# Out:
# 0.9166666666666666
