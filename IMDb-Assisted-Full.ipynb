# %% [markdown]
# # Experiments

# %%
from sereia import Sereia
from sereia.evaluation import EvaluationHandler

# %%
database_credentials = "mongodb://root:root%40server@localhost:27017/admin"
DATASET_NAME = 'imdb'

# %%
sereia = Sereia(
    DATASET_NAME,
    database_credentials,
    config_directory='./config/',
    topk_qms=99999,
    max_qm_size=5,
    max_cjn_size=3,
    topk_cjns=99999,
    topk_cjns_per_qm=1,
    assume_golden_standards_in_topk=True,
)

# %%
# sereia.create_indexes()

# %%
sereia.use_database(DATASET_NAME)

# %%
sereia.use_queryset('imdb-assisted')

# %%
sereia.load_indexes()

# %%
sereia.print_runtime_configs()
# Out:
# Maximum QM size: 5
# Top-K QMs considered: 99999
# Maximum CJN size: 3
# Top-K CJNs considered: 99999
# Maximum CJNs per QM: 1

# %%
result = sereia.run_queryset()
# Out:
# Running keyword query: clint eastwood
# Assuming golden CJN for clint eastwood in position 3
# Generated query
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'eastwood'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'clint'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$project': {'id': 1}}]

# %%
evaluation_handler = EvaluationHandler(
    DATASET_NAME,
    sereia.config,
)

evaluation_handler.load_golden_standards()

# %%
evaluated_results = evaluation_handler.evaluate_results(
    result,
    results_filename='results/' + DATASET_NAME + '-assisted-single-query',
)
# Out:
# QM Evaluation {'mrr': 0.3333333333333333, 'p@1': 0.0, 'p@2': 0.0, 'p@3': 1.0, 'p@4': 1.0, 'p@5': 1.0, 'p@6': 1.0, 'p@7': 1.0, 'p@8': 1.0, 'p@9': 1.0, 'p@10': 1.0, 'relevant_positions': [3]}
# CJN Evaluation {'mrr': 0.3333333333333333, 'p@1': 0.0, 'p@2': 0.0, 'p@3': 1.0, 'p@4': 1.0, 'p@5': 1.0, 'p@6': 1.0, 'p@7': 1.0, 'p@8': 1.0, 'p@9': 1.0, 'p@10': 1.0, 'relevant_positions': [3]}

# %%
# # # result['results'][0].qms()
# # # result['results'][0].cjns()
# # # result['results'][0].qms()
# # # sereia.index_handler.value_index['casablanca']

# sereia.execute_mongo_query('credits', 
# [{'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'clint'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  {'$set': {'cast_dup': '$cast'}},
#  {'$unwind': '$cast_dup'},
#  {'$match': {'$expr': {'$regexMatch': {'input': '$cast_dup.name',
#                                        'options': 'i',
#                                        'regex': 'eastwood'}}}},
#  {'$group': {'_id': '$_id',
#              'cast': {'$first': '$cast'},
#              'crew': {'$first': '$crew'},
#              'id': {'$first': '$id'}}},
#  # {'$project': {'id': 1}})

# %% [markdown]
# # Loading data from results file

# %%
import json

results_file = f'results/imdb-assisted.json'

# %%
with open(results_file) as f:
    results_data = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 with open(results_file) as f:
#       2     results_data = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/imdb-assisted.json'

# %%
num_qms = results_data['evaluation']['num_query_matches']
num_cns = results_data['evaluation']['num_candidate_networks']

# %%
quality_results = results_data['evaluation']
quality_results['retrieval_score']
# Out:
# [{'keyword_query': 'denzel washington',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 48,
#   'num_documents_expected': 48},
#  {'keyword_query': 'clint eastwood',
#   'precision': 1.0,
#   'recall': 0.047619047619047616,
#   'num_documents_retrieved': 3,
#   'num_documents_expected': 63},
#  {'keyword_query': 'will smith',
#   'precision': 0.016566265060240965,
#   'recall': 0.36666666666666664,
#   'num_documents_retrieved': 664,
#   'num_documents_expected': 30},
#  {'keyword_query': 'harrison ford',
#   'precision': 0.034482758620689655,
#   'recall': 0.017241379310344827,
#   'num_documents_retrieved': 29,
#   'num_documents_expected': 58},
#  {'keyword_query': 'tom hanks',
#   'precision': 0.30303030303030304,
#   'recall': 0.14084507042253522,
#   'num_documents_retrieved': 33,
#   'num_documents_expected': 71},
#  {'keyword_query': 'johnny depp',
#   'precision': 0.8333333333333334,
#   'recall': 0.07246376811594203,
#   'num_documents_retrieved': 6,
#   'num_documents_expected': 69},
#  {'keyword_query': 'angelina jolie',
#   'precision': 0.3333333333333333,
#   'recall': 0.05,
#   'num_documents_retrieved': 6,
#   'num_documents_expected': 40},
#  {'keyword_query': 'morgan freeman',
#   'precision': 0.17647058823529413,
#   'recall': 0.03529411764705882,
#   'num_documents_retrieved': 17,
#   'num_documents_expected': 85},
#  {'keyword_query': 'gone with the wind',
#   'precision': 0.0,
#   'recall': 0.0,
#   'num_documents_retrieved': 4,
#   'num_documents_expected': 1},
#  {'keyword_query': 'star wars',
#   'precision': 0.4,
#   'recall': 0.18181818181818182,
#   'num_documents_retrieved': 5,
#   'num_documents_expected': 11},
#  {'keyword_query': 'casablanca movie',
#   'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'num_documents_retrieved': 3,
#   'num_documents_expected': 1},
#  {'keyword_query': 'lord of the rings',
#   'precision': 0.0,
#   'recall': 0.0,
#   'num_documents_retrieved': 20,
#   'num_documents_expected': 4},
#  {'keyword_query': 'wizard of oz',
#   'precision': 0.21428571428571427,
#   'recall': 0.6,
#   'num_documents_retrieved': 14,
#   'num_documents_expected': 5},
#  {'keyword_query': 'the notebook',
#   'precision': 0.5,
#   'recall': 1.0,
#   'num_documents_retrieved': 4,
#   'num_documents_expected': 2},
#  {'keyword_query': 'forrest gump',
#   'precision': 1.0,
#   'recall': 1.0,
#   'num_documents_retrieved': 1,
#   'num_documents_expected': 1},
#  {'keyword_query': 'the princess bride',
#   'precision': 0.0,
#   'recall': 0.0,
#   'num_documents_retrieved': 6,
#   'num_documents_expected': 1},
#  {'keyword_query': 'the godfather',
#   'precision': 0.0,
#   'recall': 0.0,
#   'num_documents_retrieved': 3,
#   'num_documents_expected': 4},
#  {'keyword_query': 'title indiana jones',
#   'precision': 0.2,
#   'recall': 0.4,
#   'num_documents_retrieved': 10,
#   'num_documents_expected': 5},
#  {'keyword_query': 'title james bond',
#   'precision': 0.5588235294117647,
#   'recall': 0.7037037037037037,
#   'num_documents_retrieved': 34,
#   'num_documents_expected': 27},
#  {'keyword_query': 'title hannibal lecter',
#   'precision': 1.0,
#   'recall': 0.75,
#   'num_documents_retrieved': 3,
#   'num_documents_expected': 4},
#  {'keyword_query': 'title norman bates',
#   'precision': 0.6666666666666666,
#   'recall': 0.8,
#   'num_documents_retrieved': 6,
#   'num_documents_expected': 5},
#  {'keyword_query': 'title darth vader',
#   'precision': 0.8,
#   'recall': 0.4444444444444444,
#   'num_documents_retrieved': 5,
#   'num_documents_expected': 9},
#  {'keyword_query': 'name jack ryan',
#   'precision': 0.0,
#   'recall': 0.0,
#   'num_documents_retrieved': 221,
#   'num_documents_expected': 7},
#  {'keyword_query': 'name terminator',
#   'precision': 0.0,
#   'recall': 0.0,
#   'num_documents_retrieved': 2,
#   'num_documents_expected': 5},
#  {'keyword_query': 'harrison ford george lucas',
#   'precision': 0.0,
#   'recall': 0,
#   'num_documents_retrieved': 6,
#   'num_documents_expected': 0},
#  {'keyword_query': 'reeves wachowski',
#   'precision': 1.0,
#   'recall': 0.2,
#   'num_documents_retrieved': 1,
#   'num_documents_expected': 5}]

# %%
result['results'][24].qms()
# Out:
# ---
# **1st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **2nd QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **3rd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas})}
# ---
# **4th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george},crew.name{lucas})}
# ---
# **5th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas},cast.name{harrison},cast.name{ford})}
# ---
# **6th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **7th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **8th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **9th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **10th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **11th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **12th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george})}
# ---
# **13th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas})}
# ---
# **14th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **15th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **16th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **17th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **18th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **19th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **20th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **21st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **22nd QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford})}
# ---
# **23rd QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **24th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), MOVIES.v(tagline{lucas})}
# ---
# **25th QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **26th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{lucas},cast.name{harrison},cast.name{ford})}
# ---
# **27th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **28th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **29th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas})}
# ---
# **30th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **31st QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas})}
# ---
# **32nd QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **33rd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **34th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{george},crew.name{lucas})}
# ---
# **35th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford}), MOVIES.v(tagline{lucas})}
# ---
# **36th QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas})}
# ---
# **37th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **38th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), MOVIES.v(tagline{george})}
# ---
# **39th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{george},cast.name{lucas})}
# ---
# **40th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **41st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **42nd QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas})}
# ---
# **43rd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **44th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **45th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **46th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **47th QM**:
# ---
# {MOVIES.v(title{george}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **48th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **49th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **50th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **51st QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **52nd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{george},crew.name{lucas})}
# ---
# **53rd QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas})}
# ---
# **54th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.name{george},cast.name{lucas})}
# ---
# **55th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **56th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **57th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **58th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **59th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **60th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{ford},cast.name{lucas})}
# ---
# **61st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **62nd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{ford},cast.name{lucas})}
# ---
# **63rd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford})}
# ---
# **64th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **65th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **66th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(crew.name{harrison},crew.name{george})}
# ---
# **67th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), MOVIES.v(overview{george},overview{lucas})}
# ---
# **68th QM**:
# ---
# {MOVIES.v(overview{harrison},overview{george}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **69th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), MOVIES.v(overview{george},overview{ford})}
# ---
# **70th QM**:
# ---
# {MOVIES.v(overview{harrison},overview{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **71st QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), MOVIES.v(overview{harrison},overview{ford})}
# ---
# **72nd QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **73rd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{lucas})}
# ---
# **74th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george})}
# ---
# **75th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.name{ford},cast.name{lucas})}
# ---
# **76th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **77th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.name{harrison},cast.name{george})}
# ---
# **78th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{ford},cast.name{lucas})}
# ---
# **79th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{lucas}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford})}
# ---
# **80th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{george}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **81st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **82nd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas})}
# ---
# **83rd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **84th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **85th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **86th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford})}
# ---
# **87th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **88th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.character{ford},cast.character{lucas})}
# ---
# **89th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **90th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **91st QM**:
# ---
# {MOVIES.v(overview{george},overview{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **92nd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{ford},cast.character{lucas})}
# ---
# **93rd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{harrison},cast.character{ford})}
# ---
# **94th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), MOVIES.v(overview{george},overview{ford})}
# ---
# **95th QM**:
# ---
# {MOVIES.v(overview{harrison},overview{ford}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **96th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), MOVIES.v(overview{harrison},overview{ford})}
# ---
# **97th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{george}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **98th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **99th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas})}
# ---
# **100th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), MOVIES.v(overview{george},overview{lucas})}
# ---
# **101st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), MOVIES.v(overview{george},overview{ford})}
# ---
# **102nd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **103rd QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **104th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), MOVIES.v(overview{george},overview{ford},overview{lucas})}
# ---
# **105th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **106th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{ford}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **107th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.character{ford},cast.character{lucas})}
# ---
# **108th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), MOVIES.v(overview{george},overview{ford},overview{lucas})}
# ---
# **109th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.character{ford},cast.character{lucas})}
# ---
# **110th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.character{harrison},cast.character{ford})}
# ---
# **111th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **112th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **113th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **114th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), MOVIES.v(overview{harrison},overview{ford})}
# ---
# **115th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{lucas}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **116th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{george}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **117th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **118th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.character{harrison},cast.character{george})}
# ---
# **119th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **120th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **121st QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.character{harrison},cast.character{lucas})}
# ---
# **122nd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{ford},cast.name{lucas})}
# ---
# **123rd QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.character{harrison},cast.character{ford})}
# ---
# **124th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford})}
# ---
# **125th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{lucas})}
# ---
# **126th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{lucas}), MOVIES.v(overview{harrison},overview{ford})}
# ---
# **127th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george}), CREDITS.v(cast.name{ford},cast.name{lucas})}
# ---
# **128th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(cast.name{george},cast.name{lucas})}
# ---
# **129th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford})}
# ---
# **130th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.character{harrison},cast.character{lucas})}
# ---
# **131st QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(cast.character{ford},cast.character{lucas})}
# ---
# **132nd QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{harrison},cast.character{ford})}
# ---
# **133rd QM**:
# ---
# {MOVIES.v(overview{george},overview{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **134th QM**:
# ---
# {CREDITS.v(crew.name{ford},crew.name{lucas}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **135th QM**:
# ---
# {MOVIES.v(overview{harrison},overview{ford}), CREDITS.v(cast.name{george},cast.name{lucas})}
# ---
# **136th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{george})}
# ---
# **137th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{ford})}
# ---
# **138th QM**:
# ---
# {CREDITS.v(crew.name{harrison}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **139th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{lucas})}
# ---
# **140th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **141st QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{george}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **142nd QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford}), CREDITS.v(cast.character{harrison},cast.character{lucas})}
# ---
# **143rd QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{ford}), CREDITS.v(cast.name{george},cast.name{lucas})}
# ---
# **144th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george}), CREDITS.v(cast.character{ford},cast.character{lucas})}
# ---
# **145th QM**:
# ---
# {CREDITS.v(cast.name{ford},cast.name{lucas}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **146th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), MOVIES.v(overview{george},overview{lucas})}
# ---
# **147th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), MOVIES.v(overview{george},overview{ford})}
# ---
# **148th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{george})}
# ---
# **149th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(crew.name{ford})}
# ---
# **150th QM**:
# ---
# {CREDITS.v(crew.name{harrison}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **151st QM**:
# ---
# {CREDITS.v(crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **152nd QM**:
# ---
# {MOVIES.v(overview{george},overview{lucas}), MOVIES.v(overview{harrison},overview{ford})}
# ---
# **153rd QM**:
# ---
# {CREDITS.v(cast.name{ford}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **154th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{lucas})}
# ---
# **155th QM**:
# ---
# {CREDITS.v(cast.name{harrison}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **156th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{george}), CREDITS.v(cast.name{ford},cast.name{lucas})}
# ---
# **157th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(cast.character{george},cast.character{lucas})}
# ---
# **158th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.character{george},cast.character{ford})}
# ---
# **159th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), MOVIES.v(overview{lucas})}
# ---
# **160th QM**:
# ---
# {MOVIES.v(overview{harrison}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **161st QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), MOVIES.v(overview{ford})}
# ---
# **162nd QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{lucas}), MOVIES.v(overview{harrison},overview{ford})}
# ---
# **163rd QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{lucas}), MOVIES.v(overview{george},overview{ford})}
# ---
# **164th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{ford}), MOVIES.v(overview{george},overview{lucas})}
# ---
# **165th QM**:
# ---
# {CREDITS.v(cast.character{ford},cast.character{lucas}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **166th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{ford})}
# ---
# **167th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.name{lucas})}
# ---
# **168th QM**:
# ---
# {CREDITS.v(cast.name{harrison}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **169th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(crew.name{harrison})}
# ---
# **170th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.character{lucas})}
# ---
# **171st QM**:
# ---
# {CREDITS.v(cast.character{harrison}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **172nd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{ford})}
# ---
# **173rd QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford}), CREDITS.v(cast.character{harrison},cast.character{lucas})}
# ---
# **174th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{george}), CREDITS.v(cast.character{ford},cast.character{lucas})}
# ---
# **175th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{lucas}), CREDITS.v(cast.character{harrison},cast.character{ford})}
# ---
# **176th QM**:
# ---
# {MOVIES.v(overview{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **177th QM**:
# ---
# {MOVIES.v(overview{harrison}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **178th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), MOVIES.v(overview{ford})}
# ---
# **179th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), MOVIES.v(overview{george})}
# ---
# **180th QM**:
# ---
# {CREDITS.v(cast.character{harrison}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **181st QM**:
# ---
# {CREDITS.v(cast.character{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **182nd QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.name{harrison})}
# ---
# **183rd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.character{ford})}
# ---
# **184th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.character{george})}
# ---
# **185th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), MOVIES.v(overview{harrison})}
# ---
# **186th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.character{harrison})}
# ---
# **187th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford})}
# ---
# **188th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **189th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **190th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas})}
# ---
# **191st QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **192nd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **193rd QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **194th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **195th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **196th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **197th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **198th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george},crew.name{ford})}
# ---
# **199th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **200th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{george})}
# ---
# **201st QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford}), MOVIES.v(tagline{lucas})}
# ---
# **202nd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george},crew.name{ford})}
# ---
# **203rd QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george})}
# ---
# **204th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **205th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **206th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **207th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford},cast.name{lucas})}
# ---
# **208th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford},cast.name{lucas})}
# ---
# **209th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{george},crew.name{lucas},cast.name{ford},cast.name{lucas})}
# ---
# **210th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{george},crew.name{lucas},cast.name{ford},cast.name{lucas})}
# ---
# **211th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), MOVIES.v(original_title{lucas},title{lucas})}
# ---
# **212th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george},crew.name{ford})}
# ---
# **213th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george})}
# ---
# **214th QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford})}
# ---
# **215th QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **216th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.name{george},cast.name{lucas})}
# ---
# **217th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george})}
# ---
# **218th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **219th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george})}
# ---
# **220th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **221st QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **222nd QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **223rd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford},cast.name{lucas})}
# ---
# **224th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{lucas},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **225th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas})}
# ---
# **226th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george})}
# ---
# **227th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(crew.name{george},crew.name{lucas},cast.name{ford},cast.name{lucas})}
# ---
# **228th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas})}
# ---
# **229th QM**:
# ---
# {MOVIES.v(original_title{lucas},title{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **230th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), MOVIES.v(original_title{george},title{george})}
# ---
# **231st QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **232nd QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), MOVIES.v(overview{harrison},overview{ford})}
# ---
# **233rd QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **234th QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **235th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford},cast.name{lucas})}
# ---
# **236th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{george},crew.name{lucas},cast.name{ford},cast.name{lucas})}
# ---
# **237th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **238th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **239th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george})}
# ---
# **240th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **241st QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{harrison},cast.character{george})}
# ---
# **242nd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.name{ford},cast.name{lucas})}
# ---
# **243rd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **244th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{harrison},cast.character{lucas})}
# ---
# **245th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{harrison},cast.character{ford})}
# ---
# **246th QM**:
# ---
# {MOVIES.v(overview{george},overview{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **247th QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas})}
# ---
# **248th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george})}
# ---
# **249th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **250th QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **251st QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **252nd QM**:
# ---
# {MOVIES.v(overview{george},overview{ford},overview{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **253rd QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **254th QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(crew.name{harrison},crew.name{george}), MOVIES.v(tagline{lucas})}
# ---
# **255th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **256th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.character{ford},cast.character{lucas})}
# ---
# **257th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **258th QM**:
# ---
# {MOVIES.v(tagline{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **259th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford},cast.name{lucas})}
# ---
# **260th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{ford},cast.name{harrison},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **261st QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{ford},cast.name{harrison},cast.name{ford}), CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **262nd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{george},crew.name{lucas},cast.name{ford},cast.name{lucas})}
# ---
# **263rd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas},crew.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **264th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas},crew.name{ford})}
# ---
# **265th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas},crew.name{ford})}
# ---
# **266th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{george},crew.name{george},crew.name{ford})}
# ---
# **267th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **268th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(crew.name{harrison},crew.name{george}), MOVIES.v(tagline{lucas})}
# ---
# **269th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{george},crew.name{george},crew.name{lucas})}
# ---
# **270th QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **271st QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(cast.name{harrison},cast.name{george}), MOVIES.v(tagline{lucas})}
# ---
# **272nd QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{george},crew.name{lucas})}
# ---
# **273rd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas},cast.character{lucas})}
# ---
# **274th QM**:
# ---
# {MOVIES.v(tagline{george}), MOVIES.v(tagline{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **275th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{george},cast.name{lucas},crew.name{george})}
# ---
# **276th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **277th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas},cast.character{lucas})}
# ---
# **278th QM**:
# ---
# {CREDITS.v(crew.name{george},cast.name{harrison},cast.name{george}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **279th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george})}
# ---
# **280th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george}), CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford},cast.name{lucas})}
# ---
# **281st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george},crew.name{ford})}
# ---
# **282nd QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **283rd QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{ford},cast.name{harrison},cast.name{ford}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **284th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george}), CREDITS.v(crew.name{george},crew.name{lucas},cast.name{ford},cast.name{lucas})}
# ---
# **285th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{ford},cast.name{lucas})}
# ---
# **286th QM**:
# ---
# {MOVIES.v(title{george}), MOVIES.v(tagline{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **287th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **288th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.character{harrison},cast.character{ford},cast.name{harrison},cast.name{ford})}
# ---
# **289th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{lucas},cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **290th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas},crew.name{ford}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **291st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas},crew.name{ford}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **292nd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas},crew.name{ford})}
# ---
# **293rd QM**:
# ---
# {CREDITS.v(cast.character{george},cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **294th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{george},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **295th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford}), CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas})}
# ---
# **296th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford}), CREDITS.v(crew.name{harrison},crew.name{george}), MOVIES.v(tagline{lucas})}
# ---
# **297th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.name{harrison},cast.name{george}), MOVIES.v(tagline{lucas})}
# ---
# **298th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{george},crew.name{lucas})}
# ---
# **299th QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{george},cast.name{lucas})}
# ---
# **300th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{george},crew.name{george},crew.name{ford})}
# ---
# **301st QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **302nd QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(cast.name{harrison},cast.name{george}), CREDITS.v(crew.name{george},crew.name{lucas})}
# ---
# **303rd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.name{george},crew.name{george},crew.name{lucas})}
# ---
# **304th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), MOVIES.v(tagline{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **305th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **306th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{george}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **307th QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **308th QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **309th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{george})}
# ---
# **310th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **311th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), MOVIES.v(tagline{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **312th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas},cast.character{lucas})}
# ---
# **313th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **314th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george},cast.name{lucas}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas},cast.character{lucas})}
# ---
# **315th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **316th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{lucas},crew.name{george}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **317th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george})}
# ---
# **318th QM**:
# ---
# {CREDITS.v(crew.name{george},cast.name{harrison},cast.name{george}), CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **319th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **320th QM**:
# ---
# {CREDITS.v(crew.name{ford},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},cast.name{ford},crew.name{george})}
# ---
# **321st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), MOVIES.v(tagline{george}), MOVIES.v(tagline{lucas})}
# ---
# **322nd QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(cast.name{harrison},cast.name{lucas}), MOVIES.v(tagline{george})}
# ---
# **323rd QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **324th QM**:
# ---
# {CREDITS.v(crew.name{george},cast.name{harrison},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **325th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{george},cast.name{ford},cast.name{lucas})}
# ---
# **326th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george},crew.name{ford})}
# ---
# **327th QM**:
# ---
# {MOVIES.v(title{george}), MOVIES.v(tagline{lucas}), CREDITS.v(cast.name{harrison},cast.name{ford})}
# ---
# **328th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas},crew.name{george}), CREDITS.v(crew.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **329th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{harrison},cast.name{lucas},crew.name{george})}
# ---
# **330th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{george},cast.name{harrison},cast.name{ford})}
# ---
# **331st QM**:
# ---
# ...
# ---
# **3781st QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford}), CREDITS.v(cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **3782nd QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{george}), CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{lucas})}
# ---
# **3783rd QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford}), CREDITS.v(cast.character{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george})}
# ---
# **3784th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{ford},cast.name{harrison},cast.name{ford})}
# ---
# **3785th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford}), CREDITS.v(crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george})}
# ---
# **3786th QM**:
# ---
# {MOVIES.v(overview{harrison},overview{george}), CREDITS.v(cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{ford})}
# ---
# **3787th QM**:
# ---
# {MOVIES.v(overview{harrison},tagline{harrison}), MOVIES.v(overview{george},overview{lucas}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **3788th QM**:
# ---
# {CREDITS.v(cast.character{ford},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{harrison},cast.name{george}), CREDITS.v(cast.name{george},cast.name{lucas})}
# ---
# **3789th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas},crew.name{ford}), CREDITS.v(cast.character{harrison},cast.character{lucas},cast.name{george})}
# ---
# **3790th QM**:
# ---
# {MOVIES.v(overview{harrison},tagline{harrison}), CREDITS.v(crew.name{ford},crew.name{lucas}), MOVIES.v(overview{george},overview{ford})}
# ---
# **3791st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george}), MOVIES.v(overview{george},overview{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{ford})}
# ---
# **3792nd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **3793rd QM**:
# ---
# {CREDITS.v(cast.character{george},cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{lucas},cast.name{ford})}
# ---
# **3794th QM**:
# ---
# {CREDITS.v(cast.character{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **3795th QM**:
# ---
# {MOVIES.v(overview{lucas}), MOVIES.v(original_title{george},title{george}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **3796th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.name{ford}), CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george})}
# ---
# **3797th QM**:
# ---
# {CREDITS.v(cast.character{harrison}), CREDITS.v(crew.name{ford},crew.name{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george},crew.name{ford})}
# ---
# **3798th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.character{george},crew.name{lucas})}
# ---
# **3799th QM**:
# ---
# {MOVIES.v(overview{harrison},tagline{harrison}), CREDITS.v(cast.name{george},crew.name{ford},crew.name{lucas})}
# ---
# **3800th QM**:
# ---
# {MOVIES.v(original_title{george},title{george}), CREDITS.v(crew.name{ford},crew.name{lucas}), MOVIES.v(overview{harrison})}
# ---
# **3801st QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(cast.character{ford})}
# ---
# **3802nd QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{lucas})}
# ---
# **3803rd QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.character{harrison},cast.character{george}), CREDITS.v(cast.name{lucas},crew.name{george},crew.name{lucas})}
# ---
# **3804th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.character{harrison},cast.character{george}), CREDITS.v(cast.character{george},cast.character{lucas},crew.name{george})}
# ---
# **3805th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.character{george},cast.character{lucas}), CREDITS.v(crew.name{george},cast.character{harrison},cast.character{george})}
# ---
# **3806th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{ford}), CREDITS.v(cast.name{george},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{ford},cast.name{lucas})}
# ---
# **3807th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{ford})}
# ---
# **3808th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.name{lucas},crew.name{ford},crew.name{lucas})}
# ---
# **3809th QM**:
# ---
# {CREDITS.v(cast.name{lucas},crew.name{harrison},crew.name{george}), CREDITS.v(cast.character{george},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **3810th QM**:
# ---
# {CREDITS.v(cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{george},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **3811th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(cast.name{george},crew.name{george},crew.name{ford}), CREDITS.v(cast.character{ford},cast.character{lucas})}
# ---
# **3812th QM**:
# ---
# {CREDITS.v(cast.character{ford},cast.character{lucas}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george},crew.name{ford}), CREDITS.v(crew.name{harrison})}
# ---
# **3813th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.name{harrison},cast.name{george},cast.name{ford}), CREDITS.v(cast.character{george},cast.character{lucas},crew.name{george})}
# ---
# **3814th QM**:
# ---
# {CREDITS.v(crew.name{lucas}), MOVIES.v(original_title{george},title{george}), MOVIES.v(overview{harrison},overview{ford})}
# ---
# **3815th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.name{george},cast.name{ford}), MOVIES.v(tagline{lucas}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **3816th QM**:
# ---
# {CREDITS.v(crew.name{lucas}), CREDITS.v(cast.character{harrison},cast.character{ford}), CREDITS.v(cast.name{george},cast.name{ford},crew.name{george},crew.name{ford})}
# ---
# **3817th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(cast.name{ford},cast.name{lucas}), CREDITS.v(cast.name{george},crew.name{george},crew.name{lucas})}
# ---
# **3818th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), MOVIES.v(overview{george},overview{lucas}), CREDITS.v(cast.character{george},crew.name{george},crew.name{ford})}
# ---
# **3819th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.character{george},crew.name{harrison},crew.name{george}), MOVIES.v(overview{george},overview{lucas})}
# ---
# **3820th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{ford},cast.name{harrison},cast.name{ford})}
# ---
# **3821st QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.character{george},cast.character{lucas}), CREDITS.v(cast.name{harrison},crew.name{harrison},crew.name{george})}
# ---
# **3822nd QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{ford}), CREDITS.v(cast.character{george},crew.name{george},crew.name{ford}), MOVIES.v(tagline{lucas})}
# ---
# **3823rd QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{george}), MOVIES.v(tagline{lucas}), CREDITS.v(crew.name{ford},cast.name{harrison},cast.name{ford})}
# ---
# **3824th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{george},crew.name{george},crew.name{ford}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **3825th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford}), CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{lucas},crew.name{george},crew.name{lucas})}
# ---
# **3826th QM**:
# ---
# {CREDITS.v(cast.character{lucas}), CREDITS.v(cast.name{harrison},cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **3827th QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{george},crew.name{ford}), CREDITS.v(cast.character{harrison},cast.character{george}), MOVIES.v(overview{george},overview{lucas})}
# ---
# **3828th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), MOVIES.v(overview{george},overview{lucas}), CREDITS.v(cast.name{george},cast.character{harrison},cast.character{george})}
# ---
# **3829th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford}), MOVIES.v(tagline{lucas}), CREDITS.v(crew.name{ford},cast.name{harrison},cast.name{ford})}
# ---
# **3830th QM**:
# ---
# {CREDITS.v(cast.name{george},cast.name{ford},cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},cast.character{george})}
# ---
# **3831st QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george})}
# ---
# **3832nd QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(cast.character{george},cast.name{george},cast.name{lucas}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **3833rd QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford}), CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(cast.character{george},cast.character{lucas},crew.name{george})}
# ---
# **3834th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(cast.character{george},cast.character{ford},crew.name{george}), CREDITS.v(cast.character{george},cast.character{lucas})}
# ---
# **3835th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford},cast.character{lucas}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas},crew.name{ford})}
# ---
# **3836th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford},crew.name{george}), CREDITS.v(cast.name{ford},cast.name{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford})}
# ---
# **3837th QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{george}), CREDITS.v(crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{george},cast.character{ford},crew.name{george})}
# ---
# **3838th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford}), CREDITS.v(crew.name{george},cast.character{harrison},cast.character{george}), CREDITS.v(crew.name{george},crew.name{lucas})}
# ---
# **3839th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford}), CREDITS.v(cast.character{george},cast.character{lucas},cast.name{george}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **3840th QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{lucas}), CREDITS.v(cast.name{george},crew.name{george},crew.name{ford}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **3841st QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(cast.character{george},cast.name{harrison},cast.name{george}), MOVIES.v(overview{george},overview{lucas})}
# ---
# **3842nd QM**:
# ---
# {CREDITS.v(cast.character{george},cast.name{harrison},cast.name{george}), MOVIES.v(tagline{lucas}), MOVIES.v(overview{george},overview{ford})}
# ---
# **3843rd QM**:
# ---
# {CREDITS.v(cast.name{harrison},crew.name{george},crew.name{lucas}), CREDITS.v(cast.character{george},cast.name{harrison},cast.name{george},cast.name{ford})}
# ---
# **3844th QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(cast.character{george},crew.name{harrison},crew.name{george})}
# ---
# **3845th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{george}), MOVIES.v(original_title{lucas},title{lucas}), CREDITS.v(cast.name{ford})}
# ---
# **3846th QM**:
# ---
# {MOVIES.v(tagline{lucas}), CREDITS.v(crew.name{harrison},crew.name{ford}), CREDITS.v(cast.name{george},crew.name{george})}
# ---
# **3847th QM**:
# ---
# {CREDITS.v(cast.character{george},crew.name{harrison},crew.name{george}), CREDITS.v(crew.name{george},crew.name{lucas}), MOVIES.v(overview{george},overview{ford})}
# ---
# **3848th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{ford}), CREDITS.v(cast.character{george},cast.character{ford},crew.name{george}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **3849th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{ford},cast.name{george}), CREDITS.v(cast.name{george},cast.name{lucas},crew.name{ford})}
# ---
# **3850th QM**:
# ---
# {CREDITS.v(cast.character{george},crew.name{harrison},crew.name{george}), CREDITS.v(cast.character{harrison},cast.character{ford}), MOVIES.v(tagline{lucas})}
# ---
# **3851st QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(cast.character{george},cast.character{lucas},cast.name{george})}
# ---
# **3852nd QM**:
# ---
# {CREDITS.v(cast.character{ford},crew.name{george},crew.name{ford}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas},crew.name{ford})}
# ---
# **3853rd QM**:
# ---
# {MOVIES.v(tagline{ford}), CREDITS.v(cast.character{harrison},cast.character{lucas}), CREDITS.v(cast.name{george},cast.character{harrison},cast.character{george})}
# ---
# **3854th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.name{lucas},crew.name{ford},crew.name{lucas}), CREDITS.v(crew.name{george},crew.name{lucas})}
# ---
# **3855th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.name{lucas},crew.name{george},crew.name{lucas}), CREDITS.v(crew.name{ford},crew.name{lucas})}
# ---
# **3856th QM**:
# ---
# {CREDITS.v(crew.name{harrison},crew.name{george}), CREDITS.v(cast.character{george},cast.character{lucas},cast.name{george}), MOVIES.v(overview{george},overview{ford})}
# ---
# **3857th QM**:
# ---
# {CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(cast.character{george},cast.character{lucas}), MOVIES.v(overview{george},overview{ford})}
# ---
# **3858th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.character{ford},cast.character{lucas}), CREDITS.v(cast.name{george},crew.name{george},crew.name{lucas})}
# ---
# **3859th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(crew.name{ford},crew.name{lucas}), CREDITS.v(cast.character{george},cast.character{lucas},crew.name{george})}
# ---
# **3860th QM**:
# ---
# {CREDITS.v(crew.name{george},crew.name{ford},cast.name{ford}), CREDITS.v(cast.name{george},cast.name{lucas}), MOVIES.v(overview{harrison},overview{george})}
# ---
# **3861st QM**:
# ---
# {CREDITS.v(cast.character{george},cast.character{ford}), CREDITS.v(crew.name{george},crew.name{lucas}), CREDITS.v(cast.name{harrison},crew.name{harrison},crew.name{george})}
# ---
# **3862nd QM**:
# ---
# {CREDITS.v(cast.name{george},cast.character{harrison},cast.character{george}), CREDITS.v(crew.name{george},crew.name{lucas}), MOVIES.v(overview{george},overview{ford})}
# ---
# **3863rd QM**:
# ---
# {CREDITS.v(cast.character{harrison},cast.character{george}), MOVIES.v(overview{george},overview{ford}), CREDITS.v(cast.name{george},crew.name{george},crew.name{lucas})}
# ---
# **3864th QM**:
# ---
# {CREDITS.v(cast.name{harrison},cast.name{lucas}), CREDITS.v(cast.name{george},crew.name{harrison},crew.name{george}), CREDITS.v(cast.character{harrison},cast.character{ford})}
# ---
# **3865th QM**:
# ---
# {CREDITS.v(cast.character{lucas},crew.name{harrison},crew.name{george}), CREDITS.v(cast.name{harrison},cast.name{ford},cast.name{lucas},crew.name{ford})}
# ---
# **3866th QM**:
# ---
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
